# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya2k5/-Real-Time-Object-Detection-Using-YOLOv8-by-Aditya-Bhatt/blob/main/Real_Time_Object_Detection_Using_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://imgs.search.brave.com/U99epYZrNh11Zi7Nm5sClonSZE-dBzpk4bnn9hbrXq0/rs:fit:500:0:0:0/g:ce/aHR0cHM6Ly9jZG4u/Y3JlYXRlLnZpc3Rh/LmNvbS9hcGkvbWVk/aWEvc21hbGwvNzAx/ODEzOTAwL3N0b2Nr/LXBob3RvLWFmcmlj/YW4tYW1lcmljYW4t/bWFuLWhpcy1sb3lh/bC1sYWJyYWRvci1k/b2ctc3BlbmRpbmct/dGltZS10b2dldGhl/cg.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.25M/6.25M [00:00<00:00, 19.4MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (AMD EPYC 7B12)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 38.7k/38.7k [00:00<00:00, 1.71MB/s]
# image 1/1 /content/cg.jpeg: 640x448 1 person, 1 dog, 1 bowl, 1 oven, 237.0ms
# Speed: 14.5ms preprocess, 237.0ms inference, 32.7ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ![dog image.jpg](data:image/jpeg;base64,...)

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source= '/content/table.jpg' save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (AMD EPYC 7B12)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/table.jpg: 480x640 1 person, 2 laptops, 2 mouses, 137.2ms
# Speed: 3.7ms preprocess, 137.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
